# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import glob
sns.set_theme()

# %% [markdown]
# # Net - experiments

# %% [markdown]
# ## LEARNIG RATE

# %%
# get data file names
path =r'..\data\results\Net\bs8'
filenames = glob.glob(path + "/*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# %%
net_lr_test_acc = dfs[0].drop("Unnamed: 0", axis =1)
net_lr_test_loss = dfs[1].drop("Unnamed: 0", axis =1)
net_lr_train_acc = dfs[2].drop("Unnamed: 0", axis =1)
net_lr_train_loss = dfs[3].drop("Unnamed: 0", axis =1)

# %%
plt.plot(net_lr_test_acc)
plt.legend(["test " + lr for lr in net_lr_test_acc.columns])
plt.title("Small Net")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
# plt.plot(net_lr_train_acc)
# plt.legend(["train " + lr for lr in net_lr_train_acc.columns])
# plt.title("Small Net")
# plt.xlabel("Epoch")
# plt.ylabel("Accuracy")

# %%
# plt.plot(net_lr_test_loss)
# plt.legend(["test " + lr for lr in net_lr_test_loss.columns])
# plt.title("Small Net")
# plt.xlabel("Epoch")
# plt.ylabel("Loss")
# plt.show()

# plt.plot(net_lr_train_loss)
# plt.legend(["train " + lr for lr in net_lr_train_loss.columns])
# plt.title("Small Net")
# plt.xlabel("Epoch")
# plt.ylabel("Loss")
# plt.show()

# %% [markdown]
# ## BATCH SIZE

# %%
# get data file names
path =r'..\data\results\Net\lr-3'
filenames = glob.glob(path + "/*.csv")

dfs_bs = []
for filename in filenames:
    dfs_bs.append(pd.read_csv(filename))

net_bs_test_acc = dfs_bs[0].drop("Unnamed: 0", axis =1)
net_bs_test_loss = dfs_bs[1].drop("Unnamed: 0", axis =1)
net_bs_train_acc = dfs_bs[2].drop("Unnamed: 0", axis =1)
net_bs_train_loss = dfs_bs[3].drop("Unnamed: 0", axis =1)

# %%
plt.plot(net_bs_test_acc)
plt.legend(net_bs_test_acc.columns)
plt.title("Small Net - Batch size")
plt.xlabel("Epoch")
plt.ylabel("Test Accuracy")
plt.show()

# plt.plot(net_bs_train_acc)
# plt.legend(net_bs_train_acc.columns)
# plt.title("Small Net - Batch size")
# plt.xlabel("Epoch")
# plt.ylabel("Train Accuracy")
# plt.show()

# %%
# plt.plot(net_bs_test_loss)
# plt.legend(net_bs_test_loss.columns)
# plt.title("Small Net - Batch Size")
# plt.xlabel("Epoch")
# plt.ylabel("Test Loss")
# plt.show()

# plt.plot(net_bs_train_loss)
# plt.legend(net_bs_train_loss.columns)
# plt.title("Small Net - Batch Size")
# plt.xlabel("Epoch")
# plt.ylabel("Train Loss")
# plt.show()

# %% [markdown]
# # NET_DROPOUT

# %% [markdown]
# BATCH SIZE: 8
# LEARNIG RATE: 10e-3

# %%
import glob

# get data file names
path =r'..\data\results\Net_dropout\bs8_ep30_lr-3'
filenames = glob.glob(path + "/*.csv")

dfs_dr = []
for filename in filenames:
    dfs_dr.append(pd.read_csv(filename))

net_dr_test_acc = dfs_dr[0].drop("Unnamed: 0", axis =1)
net_dr_test_loss = dfs_dr[1].drop("Unnamed: 0", axis =1)
net_dr_train_acc = dfs_dr[2].drop("Unnamed: 0", axis =1)
net_dr_train_loss = dfs_dr[3].drop("Unnamed: 0", axis =1)

# %%
plt.plot(net_dr_test_acc)
plt.legend(net_dr_test_acc.columns)
plt.title("Small Net - dropout")
plt.xlabel("Epoch")
plt.ylabel("Test Accuracy")
plt.ylim((0.2,0.8))
plt.show()

# plt.plot(net_dr_train_acc)
# plt.legend(net_dr_train_acc.columns)
# plt.title("Small Net - dropout")
# plt.xlabel("Epoch")
# plt.ylabel("Train Accuracy")
# plt.ylim((0,1))
# plt.show()

# %%
plt.plot(net_dr_test_loss, alpha = 0.8)
plt.legend(net_dr_test_loss.columns)
plt.title("Small Net - dropout")
plt.xlabel("Epoch")
plt.ylabel("Test Loss")

plt.show()

# plt.plot(net_dr_train_loss, alpha = 0.8)
# plt.legend(net_dr_train_loss.columns)
# plt.title("Small Net - dropout")
# plt.xlabel("Epoch")
# plt.ylabel("Train Loss")

# plt.show()

# %% [markdown]
# WEIGHT DECAY - without dropout

# %%
import glob

# get data file names
path =r'..\data\results\Net\bs8_ep30_lr-3_wd'
filenames = glob.glob(path + "/*.csv")

dfs_dr = []
for filename in filenames:
    dfs_dr.append(pd.read_csv(filename))

net_wd_test_acc = dfs_dr[0].drop("Unnamed: 0", axis =1)
net_wd_test_loss = dfs_dr[1].drop("Unnamed: 0", axis =1)
net_wd_train_acc = dfs_dr[2].drop("Unnamed: 0", axis =1)
net_wd_train_loss = dfs_dr[3].drop("Unnamed: 0", axis =1)

plt.plot(net_wd_test_acc)
plt.legend(net_wd_test_acc.columns)
plt.title("Small Net - weight decay")
plt.xlabel("Epoch")
plt.ylabel("Test Accuracy")
plt.ylim((0,1))
plt.show()

# plt.plot(net_wd_train_acc)
# plt.legend(net_wd_train_acc.columns)
# plt.title("Small Net - weight decay")
# plt.xlabel("Epoch")
# plt.ylabel("Train Accuracy")
# plt.show()

# plt.plot(net_wd_test_loss)
# plt.legend(net_wd_test_loss.columns)
# plt.title("Small Net - weight decay")
# plt.xlabel("Epoch")
# plt.ylabel("Test Loss")
# plt.show()

# plt.plot(net_wd_train_loss, alpha = 0.8)
# plt.legend(net_wd_train_loss.columns)
# plt.title("Small Net - weight decay")
# plt.xlabel("Epoch")
# plt.ylabel("Train Loss")
# plt.show()

# %% [markdown]
# # BIGGER NET WITH DROPOUT

# %%
bigger_net = pd.read_csv(r'..\data\results\Net_dropout_new\bs8_ep30_lr-3_dr25\dropouts_bigger_train_test_final.csv', sep=";")
plt.plot(bigger_net[["test_acc", "train_acc"]])
plt.legend(["test", "train"])
plt.title("Bigger Net with dropout = 0.25 ")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.show()
# plt.plot(bigger_net[["test_loss", "train_loss"]])
# plt.legend(["test", "train"])
# plt.title("Bigger Net with dropout = 0.25 ")
# plt.ylabel("Loss")
# plt.xlabel("Epoch")
# plt.show()

# %% [markdown]
# ## Bigger Net adam DR 0.2

# %%
import glob

# get data file names
path =r'..\data\results\Net_dropout_new\bsexp_ep40_lr-3_dr20_adam'
filenames = glob.glob(path + "/*.csv")

dfs_dr = []
for filename in filenames:
    dfs_dr.append(pd.read_csv(filename))

net_test_acc = dfs_dr[0].drop("Unnamed: 0", axis =1)
net_test_loss = dfs_dr[1].drop("Unnamed: 0", axis =1)
net_train_acc = dfs_dr[2].drop("Unnamed: 0", axis =1)
net_train_loss = dfs_dr[3].drop("Unnamed: 0", axis =1)

plt.plot(net_test_acc.loc[:30,"8"])
plt.plot(net_train_acc.loc[:30, "8"])
#plt.legend(net_test_acc.columns)
plt.title("Bigger Net with dropout and ADAM vs SGD")
# plt.show()

plt.plot(bigger_net[["test_acc", "train_acc"]])
plt.legend(["test ADAM", "train ADAM", "test SGD", "train SGD"])
plt.ylabel("Accuracy")
plt.xlabel("Epoch")

#plt.legend(net_train_acc.columns)
# plt.title("Big Net with dropout 0.2 and ADAM - Accuracy - Train")
plt.show()

# plt.plot(net_test_loss, alpha = 0.8)
# plt.legend(net_test_loss.columns)
# plt.title("Big Net with dropout 0.2 and ADAM - Loss - Test")
# plt.show()

# plt.plot(net_train_loss, alpha = 0.8)
# plt.legend(net_train_loss.columns)
# plt.title("Big Net with dropout 0.2 and ADAM - Loss - Train")
# plt.show()

# %% [markdown]
# ## RESNET18_1

# %%
df_16 = pd.read_csv("..\\data\\results\\resnet18_1\\bs16_epoch30_lr-3\\resnet18_1.csv")

df_8 = pd.read_csv("..\\data\\results\\resnet18_1\\bs8_epoch30_lr-3\\resnet18_1.csv")

plt.plot(df_16[["test_acc", "train_acc"]])
plt.plot(df_8[["test_acc", "train_acc"]])
plt.legend(["test bs:16", "train bs:16", "test bs:8", "train bs:8"])
plt.title("Resnet18 -  Accuracy")
plt.show()

plt.plot(df_16[["test_loss", "train_loss"]])
plt.plot(df_8[["test_acc", "train_acc"]])
plt.legend(["test bs:16", "train bs:16", "test bs:8", "train bs:8"])
plt.title("Resnet18 Loss")
plt.show()

# %% [markdown]
# # RESNET_18_1 Adam bs1024

# %%
test_acc = pd.read_csv("..\\data\\results\\resnet18_1\\bs1024_epoch35_lr-3_ADAM\\resnet18_1_test_acc_history.csv")
train_acc = pd.read_csv("..\\data\\results\\resnet18_1\\bs1024_epoch35_lr-3_ADAM\\resnet18_1_train_acc_history.csv")

ADAM_df_8 = pd.read_csv("..\\data\\results\\resnet18_1\\ADAM_bs8_epoch30_lr-3\\resnet18_1.csv")

# test_loss = pd.read_csv("..\\data\\results\\resnet18_1\\bs1024_epoch35_lr-3_ADAM\\resnet18_1_test_loss_history.csv")
# train_loss = pd.read_csv("..\\data\\results\\resnet18_1\\bs1024_epoch35_lr-3_ADAM\\resnet18_1_train_loss_history.csv")

test_acc.drop("Unnamed: 0", axis = 1, inplace = True)
train_acc.drop("Unnamed: 0", axis = 1, inplace = True)
# test_loss.drop("Unnamed: 0", axis = 1, inplace = True)
# train_loss.drop("Unnamed: 0", axis = 1, inplace = True)



plt.plot(test_acc["1024"])
plt.plot(ADAM_df_8[["test_acc", "train_acc"]])
plt.title("Resnet18, ADAM, Fully Connected trained")
plt.plot(train_acc["1024"])
plt.legend(["test, bs:1024", "train, bs:1024", "test, bs:8", "train, bs:8"])
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.ylim((0.35,1))
plt.xlim((0,30))
plt.show()

# %% [markdown]
# ## resnet18_2 SGD batch size exp

# %%
test_acc = pd.read_csv("..\\data\\results\\resnet18_2\\SGD_ep30_lr-3\\batch_test_acc_history.csv")

train_acc = pd.read_csv("..\\data\\results\\resnet18_2\\SGD_ep30_lr-3\\batch_train_acc_history.csv")
test_loss = pd.read_csv("..\\data\\results\\resnet18_2\\SGD_ep30_lr-3\\batch_test_loss_history.csv")
train_loss = pd.read_csv("..\\data\\results\\resnet18_2\\SGD_ep30_lr-3\\batch_train_loss_history.csv")


plt.plot(test_acc)
plt.legend(test_acc.columns)
plt.title("Resnet18 Last layer trained")
plt.ylabel("Test Accuracy")
plt.xlabel("Epoch")
plt.ylim((0.6,1))
plt.show()


# plt.plot(train_acc)
# plt.legend(train_acc.columns)
# plt.title("Resnet18 Last layer trained -  Accuracy - Train")
# plt.show()

# plt.plot(test_loss)
# plt.legend(test_loss.columns)
# plt.title("Resnet18 Last layer trained -  Loss - Test")
# plt.show()


# plt.plot(train_loss)
# plt.legend(train_loss.columns)
# plt.title("Resnet18 Last layer trained -  Loss - Train")
# plt.show()

# %% [markdown]
# # Resnet18_2 ADAM vs SGD BS:8, LR:10-3

# %%
resnet_adam = pd.read_csv(r"..\data\results\resnet18_2\ADAM_bs8_ep30_lr-3\resnet18_2.csv")
resnet_sgd_test = pd.read_csv("..\\data\\results\\resnet18_2\\SGD_ep30_lr-3\\batch_test_acc_history.csv")
resnet_sgd_train = pd.read_csv("..\\data\\results\\resnet18_2\\SGD_ep30_lr-3\\batch_train_acc_history.csv")

resnet_sgd_test = resnet_sgd_test[["8"]]
resnet_sgd_train = resnet_sgd_train[["8"]]
plt.plot(resnet_sgd_test)
plt.plot(resnet_sgd_train)
plt.plot(resnet_adam[["test_acc", "train_acc"]])
plt.legend(["test SGD", "train SGD", "test ADAM", "train ADAM"])
plt.title("Resnet18 Last layer trained")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.ylim((0.6,1))
plt.show()

# %% [markdown]
# # Resnet18_2 ADAM BS: 8 LR: 10-3 Step Size: 5, G: 0.5, WD: 0.01

# %%
resnet_adam_decrease = pd.read_csv("..\\data\\results\\resnet18_2\\ADAM_bs8_ep30_lr-3_ss5_g0_5_wd0_01\\resnet18_2.csv")

plt.plot(resnet_adam_decrease[["test_acc", "train_acc"]])
plt.legend(["test ","train"])
plt.title("Resnet18 Last layer trained")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.ylim((0.6,1.02))
plt.show()

# %% [markdown]
# # AUGMENTATION

# %%
augm_net = pd.read_csv(r'..\data\results\Net\SGD_augm_bs8\net_SGD_augm_history.csv')


net =pd.read_csv(r'..\data\results\Net\lr-3\batch_test_acc_history.csv')

net = net.drop("Unnamed: 0", axis =1)



plt.plot(augm_net[["test_acc", "train_acc"]])
plt.plot(net["8"])
plt.legend(["test AUGM", "train AUGM", "test without AUGM"])
plt.title("Net, SGD, BS:8 with AUGM -  Accuracy")
# Out:
# Text(0.5, 1.0, 'Net, SGD, BS:8 with AUGM -  Accuracy')

# %%
augm_net = pd.read_csv(r'..\data\results\Net_dropout\SGD_augm_bs8_dr0_35\net_SGD_augm_history.csv')

net_dr =pd.read_csv(r'..\data\results\Net_dropout\bs8_ep30_lr-3\dropouts_test_acc_history.csv')


net_dr = net_dr.drop("Unnamed: 0", axis =1)


plt.plot(augm_net[["test_acc", "train_acc"]])
plt.plot(net_dr["0.35"])
plt.legend(["test AUGM", "train AUGM", "test without AUGM"])
plt.title("Net with droput 0.35, SGD, BS:8 with AUGM -  Accuracy")
# Out:
# Text(0.5, 1.0, 'Net with droput 0.35, SGD, BS:8 with AUGM -  Accuracy')

# %%
augm_net = pd.read_csv(r'..\data\results\Net_dropout\SGD_augm_addingimg_bs8_dr0_1\net_SGD_augm_history.csv')

net_dr =pd.read_csv(r'..\data\results\Net_dropout\SGD_bs8_dr0_1\net_SGD_history.csv')


plt.plot(augm_net[["test_acc", "train_acc"]])
plt.plot(net_dr[["test_acc", "train_acc"]])
plt.legend(["test AUGM", "train AUGM", "test without AUGM", "test without AUGM"])
plt.title("Small Net, droput: 0.1, BS:8")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.ylim((0.35, 1))
# Out:
# (0.35, 1.0)

# %%
augm_net = pd.read_csv(r'..\data\results\Net_dropout_new\augm_SGD_bs8_dr25\bnet_augm_history.csv')

bigger_net = pd.read_csv(r'..\data\results\Net_dropout_new\bs8_ep30_lr-3_dr25\dropouts_bigger_train_test_final.csv', sep =";")
plt.plot(augm_net[["test_acc", "train_acc"]])
plt.plot(bigger_net[["test_acc", "train_acc"]])
plt.legend(["test AUGM", "train AUGM", "test without AUGM", "train without AUGM"])
plt.title("Bigger Net with droput 0.25, SGD, BS:8 with AUGM -  Accuracy")
# Out:
# Text(0.5, 1.0, 'Bigger Net with droput 0.25, SGD, BS:8 with AUGM -  Accuracy')

# %%
augm_net = pd.read_csv(r'..\data\results\Net_dropout_new\augm_adam_bs64_dr20\bnet_augm_history.csv')

bigger_net = pd.read_csv(r'..\data\results\Net_dropout_new\adam_bs64_dr20\bnet_augm_history.csv')


plt.plot(augm_net[["test_acc", "train_acc"]])
plt.plot(bigger_net[["test_acc", "train_acc"]])

plt.legend(["test AUGM", "train AUGM",  "test without AUGM", "train without AUGM"])
plt.title("Bigger Net, droput 0.2, ADAM, BS:64")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.ylim((0.35, 1))
plt.show()

# %% [markdown]
# Resnet 18_2

# %%
augm_resnet = pd.read_csv(r"..\data\results\resnet18_2\augm_ADAM_bs8_ep30_lr-3_ss5_g0_5_wd0_01\resnet2_augm_history.csv")




resnet_adam = pd.read_csv("..\\data\\results\\resnet18_2\\ADAM_bs8_ep30_lr-3_ss5_g0_5_wd0_01\\resnet18_2.csv")


plt.plot(augm_resnet[["test_acc", "train_acc"]])
plt.plot(resnet_adam[["test_acc", "train_acc"]])
plt.legend(["test augm","train augm", "test without augm", "train without augm"])
plt.title("Resnet18 Last layer trained")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.xlim((0,30))
plt.ylim((0.35,1.02))
plt.show()
